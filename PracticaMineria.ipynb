# %%
import json
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sn

# %%
df = pd.read_csv("unclean_data1.csv")

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df = pd.read_csv("unclean_data1.csv",encoding='utf8')

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.shape
# Out:
# (14, 16)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# ...

# %%
df.rename(columns = {'movie_title':'titulo'})
# Out:
#                                           titulo  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
N = len(df.index)

# %%
print(N)
# Out:
# 14

# %%
df_copy = df.copy()

# %%
df_copy.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df_copy.rename(columns = {'movie_title':'titulo'})
df_copy = df_copy.rename(columns = {'num_critic_for_reviews':'num_criticas'})
df_copy.rename(columns = {'duration':'duracion'})
df_copy.rename(columns = {'DIRECTOR_facebook_likes':'num_likes_dir'})
df_copy.rename(columns = {'ACTOR_1_facebook_likes':'num_likes_a1'})
df_copy.rename(columns = {'actor_3_facebook_likes':'num_likes_a3'})
df_copy.rename(columns = {'Cast_Total_facebook_likes':'tot_likes'})
df_copy.rename(columns = {'facenumber_in_poster':'fn_poster'})
df_copy.rename(columns = {'num_user_for_reviews':'num_rev'})
df_copy.rename(columns = {'ACTOR_2_facebook_likes':'num_likes_a2'})
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df_copy.drop('title_year.1',axis=1)
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df_copy.drop(index=8)
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# ...

# %%
df_copy1 = df_copy.copy()

# %%
df_copy1drop = df_copy1.dropna()

# %%
df_copy1drop.head()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
df_copy1drop = df_copy1.dropna(axis=1)

# %%
df_copy1drop.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    actor_3_facebook_likes  ACTOR_1_facebook_likes      gross  \
# 0                     855                    1000  760505847
# 1                    1000                   40000  309404152
# 2                     161                   11000  200074175
# 3                   23000                   27000  448130642
# 4                     530                     640   73058679
#
#    num_user_for_reviews     budget  title_year  imdb_score
# 0                  3054  237000000        2009         7.9
# ...

# %%
df_copy1drop.drop('actor_3_facebook_likes',axis=1)
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df1 = df_copy1drop.drop('ACTOR_1_facebook_likes',axis=1)

# %%
df1.drop(index=8)
df1 = df1.drop('actor_3_facebook_likes',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-bf6af9f1ec4d> in <module>
#       1 df1.drop(index=8)
# ----> 2 df1 = df1.drop('actor_3_facebook_likes',axis=1)
#       3 df1.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df1.show()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df1.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#        gross  num_user_for_reviews     budget  title_year  imdb_score
# 0  760505847                  3054  237000000        2009         7.9
# 1  309404152                  1238  300000000        2007         7.1
# 2  200074175                   994  245000000        2015         6.8
# 3  448130642                  2701  250000000        2012         8.5
# 4   73058679                   738  263700000        2012         6.6

# %%
df1 = df1.drop(index=8)

# %%
df1
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# ...

# %%
#¿Para que me puede servir estas practicas de agrupaciones para la practica siguiente
##Elimina datos repetidos,asi el manejo de la informacion sera maas facil ya que no se trabajara con datos inutiles

# %%
#Importancia del analisis previo de los datos antes de iniciar las modificaciones
##Esto nos llevara a tener un mejor preprocesamientos de los datos ya que si no analizamos antes podemos eliminar 
##datos que nos sirvan para nuestra investigacion.
