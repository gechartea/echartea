# %%
# %matplotlib inline

# %%
import json
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sn

# %%
df = pd.read_csv("winemag-data_first150k.csv")

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
import pandas_profiling
#libreria para generar htmkl de nuestra bdd

# %%
df.shape
# Out:
# (150930, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
df= df.drop('Unnamed: 0',axis=1)
#Eliminamos la columna Unnamed: 0 ya que solo nos esta dando el mismo dato que el index por ende no es necesaria

# %%
df
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]>

# %%
percent= 100*(len(df.loc[:,df.isnull().sum(axis=0)>=1 ].index) / len(df.index))

# %%
print(percent)
# Out:
# 100.0

# %%
df.isnull().mean() * 100
# Out:
# country         0.003313
# description     0.000000
# designation    30.302127
# points          0.000000
# price           9.073743
# province        0.003313
# region_1       16.603724
# region_2       59.615053
# variety         0.000000
# winery          0.000000
# dtype: float64

# %%
df= df.drop('region_2',axis=1)
#Al hacer un analisis de los datos esta columna no no es de importancia ya que su porcentaje de valores nulos es alto y l
#los datos que tiene la mayoria son parecidos a las columna region_1

# %%
df
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1             variety  \
# 0               California        Napa Valley  Cabernet Sauvignon
# 1           Northern Spain               Toro       Tinta de Toro
# 2               California     Knights Valley     Sauvignon Blanc
# 3                   Oregon  Willamette Valley          Pinot Noir
# 4                 Provence             Bandol  Provence red blend
# ...                    ...                ...                 ...
# 150925      Southern Italy  Fiano di Avellino         White Blend
# 150926           Champagne          Champagne     Champagne Blend
# 150927      Southern Italy  Fiano di Avellino         White Blend
# 150928           Champagne          Champagne     Champagne Blend
# 150929  Northeastern Italy         Alto Adige        Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# 2                      Macauley
# 3                         Ponzi
# 4          Domaine de la Bégude
# ...                         ...
# 150925    Feudi di San Gregorio
# 150926                H.Germain
# 150927                Terredora
# 150928                   Gosset
# 150929            Alois Lageder
#
# [150930 rows x 9 columns]

# %%
df['points'].describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
media_puntaje = df['points'].mean()

# %%
clase_1 = df[df['points']>=media_puntaje]

# %%
clase_1
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1             variety  \
# 0               California        Napa Valley  Cabernet Sauvignon
# 1           Northern Spain               Toro       Tinta de Toro
# 2               California     Knights Valley     Sauvignon Blanc
# 3                   Oregon  Willamette Valley          Pinot Noir
# 4                 Provence             Bandol  Provence red blend
# ...                    ...                ...                 ...
# 150925      Southern Italy  Fiano di Avellino         White Blend
# 150926           Champagne          Champagne     Champagne Blend
# 150927      Southern Italy  Fiano di Avellino         White Blend
# 150928           Champagne          Champagne     Champagne Blend
# 150929  Northeastern Italy         Alto Adige        Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# 2                      Macauley
# 3                         Ponzi
# 4          Domaine de la Bégude
# ...                         ...
# 150925    Feudi di San Gregorio
# 150926                H.Germain
# 150927                Terredora
# 150928                   Gosset
# 150929            Alois Lageder
#
# [79002 rows x 9 columns]

# %%
#Calculamos la media del puntaje de los vinos de nuestra BDD y armamos una clase con los vinos que su puntaje es igual
#o mayor a la media y es con lo que vamos a trabajar

# %%
df['country'].value_counts().head(10).plot.bar()

# %%
#Con esta grafica podemosver que la mayoria de los vinos con "un buen puntaje" basado en que son mayores que la 
#media se hacen EUA por ende al buscar vinos de mejores calidad al buscar proveedores EUA seria uno de los principales

# %%
df['points'].value_counts().sort_index().plot.bar()

# %% [markdown]
# ### Pregunta 1
# La grafica represetan las calificaciones y cual es la mas frcuente de estas siendo la calificacion de 87
# esto se puedo inferir al momento que calculamos nuestra media que fue de 87.888418

# %%
df.winery.unique()
# Out:
# array(['Heitz', 'Bodega Carmen Rodríguez', 'Macauley', ..., 'Screwed',
#        'Red Bucket', 'White Knot'], dtype=object)

# %%
len(df.winery.unique())
# Out:
# 14810

# %%
df['winery'].count()
# Out:
# 150930

# %%
df['price'].describe()
# Out:
# count    137235.000000
# mean         33.131482
# std          36.322536
# min           4.000000
# 25%          16.000000
# 50%          24.000000
# 75%          40.000000
# max        2300.000000
# Name: price, dtype: float64

# %%
df['points'].describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
df[df['price'] < 100].sample(100).plot.scatter(x='price', y='points')

# %% [markdown]
# #La grafica no me dio los resultados que esperaba ya que por los puntos no me daba la relacion que esperaba entre precio y puntaje

# %%
df[df['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %% [markdown]
# Aqui es un poco mas visible que la media del puntaje es donde se encuentra aproximadamente la media del precio dando como resultado que la calidad si esta relacionada completamente al precio

# %%
dfsn = df[df['price']>87.5]

# %% [markdown]
# Creamos un nuevo dataframe donde solo tomaremos en cuenta a los que su precio sea mayor a la media ya que son los mas rentables

# %%
sn.countplot(dfsn['price'])

# %% [markdown]
# Al ser muchos datos la grafica no da los resultados obtenidos

# %%
dfsnn = dfsn.head(15)

# %% [markdown]
# Hacemos un sub DF donde traemos los 15 precios mas altos

# %%
sn.countplot(dfsnn['price'])

# %% [markdown]
# Con esta grafica obtenemos una media de los precios mas altos asi nos da un margen de venta y basado en las graficas anteriores como el precio esta ligado al puntaje y los vinos con puntaje mas alto lo mas probable es que la mayoria de los vinos con estos precios provengan de estados unidos

# %%
sn.countplot(dfsn['points'])

# %% [markdown]
# Aqui vemos la variacion de puntajes dentro de nuestros vinos podemos observar que muchos de los vinos tienen una calidad encima del promedio por ende se consideran de buena calidad.

# %% [markdown]
# rev-solo.csv

# %%
dfp12 = pd.read_csv("rev-solo.csv")

# %%
import sys
# !conda install --yes --prefix {sys.prefix} nltk
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\gusta\Anaconda3
#
#   added / updated specs:
#     - nltk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |           py37_0         2.8 MB
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following packages will be UPDATED:
#
#   conda                     conda-forge::conda-4.8.2-py37_0 --> pkgs/main::conda-4.8.3-py37_0
#
#
#
# Downloading and Extracting Packages
#
# conda-4.8.3          | 2.8 MB    |            |   0%
# conda-4.8.3          | 2.8 MB    |            |   1%
# conda-4.8.3          | 2.8 MB    | 8          |   8%
# conda-4.8.3          | 2.8 MB    | ##6        |  26%
# conda-4.8.3          | 2.8 MB    | ###2       |  33%
# conda-4.8.3          | 2.8 MB    | #####7     |  57%
# conda-4.8.3          | 2.8 MB    | #######2   |  72%
# conda-4.8.3          | 2.8 MB    | ########1  |  82%
# conda-4.8.3          | 2.8 MB    | #########1 |  91%
# conda-4.8.3          | 2.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import nltk
import ssl
if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
from nltk.corpus import stopwords
print(stopwords.words("english")[:10])
from nltk.sentiment.vader import SentimentIntensityAnalyzer
s = SentimentIntensityAnalyzer() # en inglés hasta podemos distinguir entre palabras positivas y negativas
print(s.polarity_scores('useless'))
print(s.polarity_scores('marvelous'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gusta\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gusta\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\gusta\AppData\Roaming\nltk_data...
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}

# %%
dfp12
# Out:
#        Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.  \
# 0       This is ripe and fruity a wine that is smooth ...
# 1       Tart and snappy the flavors of lime flesh and ...
# 2       Pineapple rind lemon pith and orange blossom s...
# 3       Much like the regular bottling from 2012 this ...
# 4       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129967  Notes of honeysuckle and cantaloupe sweeten th...
# 129968  Citation is given as much as a decade of bottl...
# 129969  Well-drained gravel soil gives this wine its c...
# 129970  A dry style of Pinot Gris this is crisp with s...
# 129971  Big rich and off-dry this is powered by intens...
#
#            Italy         White Blend
# 0       Portugal      Portuguese Red
# 1             US          Pinot Gris
# 2             US            Riesling
# 3             US          Pinot Noir
# 4          Spain  Tempranillo-Merlot
# ...          ...                 ...
# 129967   Germany            Riesling
# 129968        US          Pinot Noir
# 129969    France      Gewürztraminer
# 129970    France          Pinot Gris
# 129971    France      Gewürztraminer
#
# [129972 rows x 3 columns]

# %%
dfp12 = dfp12.rename(columns = {'Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.':'description'})
# Out:
#   File "<ipython-input-50-52738f795872>", line 1
#     dfp12 = dfp12.rename(columns = {'Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.':'description'})
#                                                                                                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# Tuve un error al cargar la BDD donde el primer registro me lo cargo como la descripcion de la columna pero no supe como arreglarlo

# %%
dfp12
# Out:
#        Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.  \
# 0       This is ripe and fruity a wine that is smooth ...
# 1       Tart and snappy the flavors of lime flesh and ...
# 2       Pineapple rind lemon pith and orange blossom s...
# 3       Much like the regular bottling from 2012 this ...
# 4       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129967  Notes of honeysuckle and cantaloupe sweeten th...
# 129968  Citation is given as much as a decade of bottl...
# 129969  Well-drained gravel soil gives this wine its c...
# 129970  A dry style of Pinot Gris this is crisp with s...
# 129971  Big rich and off-dry this is powered by intens...
#
#        description             variety
# 0         Portugal      Portuguese Red
# 1               US          Pinot Gris
# 2               US            Riesling
# 3               US          Pinot Noir
# 4            Spain  Tempranillo-Merlot
# ...            ...                 ...
# 129967     Germany            Riesling
# 129968          US          Pinot Noir
# 129969      France      Gewürztraminer
# 129970      France          Pinot Gris
# 129971      France      Gewürztraminer
#
# [129972 rows x 3 columns]

# %%
dfp12 = dfp12.rename(columns = {'description':'country'})

# %%
clase_1 = dfp12[dfp12['country']=='US']

# %% [markdown]
# Creamos una clase nueva donde filtramos nuestros registros por pais, el pais que elegimos es US debido a que como vimos en las graficas anteriores es el de mayor rentabilidad ya que produce los mejores vinos.

# %%
clase_1
# Out:
#        Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.  \
# 1       Tart and snappy the flavors of lime flesh and ...
# 2       Pineapple rind lemon pith and orange blossom s...
# 3       Much like the regular bottling from 2012 this ...
# 9       Soft supple plum envelopes an oaky structure i...
# 11      Slightly reduced this wine offers a chalky tan...
# ...                                                   ...
# 129946  Hailing from one of the more popular vineyards...
# 129950  There's no bones about the use of oak in this ...
# 129951  This opens with herbaceous dollops of thyme an...
# 129953  This Zinfandel from the eastern section of Nap...
# 129968  Citation is given as much as a decade of bottl...
#
#        country             variety
# 1           US          Pinot Gris
# 2           US            Riesling
# 3           US          Pinot Noir
# 9           US  Cabernet Sauvignon
# 11          US  Cabernet Sauvignon
# ...        ...                 ...
# 129946      US        Chenin Blanc
# 129950      US          Chardonnay
# 129951      US           Zinfandel
# 129953      US           Zinfandel
# 129968      US          Pinot Noir
#
# [54504 rows x 3 columns]

# %%
clase_1.head(50)
# Out:
#     Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.  \
# 1    Tart and snappy the flavors of lime flesh and ...
# 2    Pineapple rind lemon pith and orange blossom s...
# 3    Much like the regular bottling from 2012 this ...
# 9    Soft supple plum envelopes an oaky structure i...
# 11   Slightly reduced this wine offers a chalky tan...
# 13   Building on 150 years and six generations of w...
# 18   Red fruit aromas pervade on the nose with ciga...
# 19   Ripe aromas of dark berries mingle with ample ...
# 20   A sleek mix of tart berry stem and herb along ...
# 22   This wine from the Geneseo district offers aro...
# 24   Oak and earth intermingle around robust aromas...
# 28   Clarksburg is becoming a haven for Chenin Blan...
# 32   Rustic and dry this has flavors of berries cur...
# 33   This shows a tart green gooseberry flavor that...
# 34   As with many of the Erath 2010 vineyard design...
# 40   A stiff tannic wine this slowly opens and brin...
# 42   The clean brisk mouthfeel gives this slightly ...
# 44   Right out of the starting blocks this is an oa...
# 46   This is a sweet wine with flavors of white sug...
# 47   This bottling resembles the New Zealand paradi...
# 54   This shows jelly-like flavors of orange and pe...
# 55   This is weighty creamy and medium to full in b...
# 58   Aromas of cranberry barrel spice and herb are ...
# 59   Syrupy and dense this wine is jammy in plum an...
# 61   The aromas are brooding with notes of barrel s...
# 63   There are intriguing touches to the nose of th...
# 66   A blend of Merlot and Cabernet Franc this wine...
# 67   Very deep in color and spicy-smoky in flavor t...
# 69   Aromas of vanilla char and toast lead to light...
# 70   Big oak defines this robustly dense and extrac...
# 72   Juicy plum raspberry and pencil lead lead the ...
# 73   This is the producer's first release of this w...
# 74   This is made from equal parts Cabernet Franc a...
# 77   Some rosés are made simply by bleeding the jui...
# 83   A healthy addition of 13% Petite Sirah provide...
# 85   Vibrant aromas of ripe pear white flowers and ...
# 86   Softened tannins surround a light-bodied lean ...
# 89   This blend of Sangiovese Malbec Cabernet Sauvi...
# 90   This wine has a touch of perceptible sweetness...
# 91   All red Bordeaux varieties are represented in ...
# 93   Barrel notes are prominent with aromas of Crea...
# 96   A wisp of bramble extends a savory tone from n...
# 98   This blends 20% each of all five red-Bordeaux ...
# 99   Fresh apple lemon and pear flavors are accente...
# 100  Dusty mineral smoke and struck flint lend a sa...
# 101  Intensely smoky tones of struck flint and ash ...
# 107  Lots of spearmint coyote mint hot licorice gin...
# 110  This 100% varietal wine opens in a heady aroma...
# 113  Tar dried meat olallieberry and sharp cedar ar...
# 114  Poached pears yellow apples and a touch of but...
#
#     country                   variety
# 1        US                Pinot Gris
# 2        US                  Riesling
# 3        US                Pinot Noir
# 9        US        Cabernet Sauvignon
# 11       US        Cabernet Sauvignon
# 13       US                Chardonnay
# 18       US                  Meritage
# 19       US                 Red Blend
# 20       US                Pinot Noir
# 22       US                    Merlot
# 24       US                Pinot Noir
# 28       US              Chenin Blanc
# 32       US                 Red Blend
# 33       US           Sauvignon Blanc
# 34       US                Pinot Noir
# 40       US                Pinot Noir
# 42       US           Sauvignon Blanc
# 44       US                 Red Blend
# 46       US                  Riesling
# 47       US           Sauvignon Blanc
# 54       US                Chardonnay
# 55       US                Chardonnay
# 58       US                    Malbec
# 59       US        Cabernet Sauvignon
# 61       US            Cabernet Franc
# 63       US           Sauvignon Blanc
# 66       US  Bordeaux-style Red Blend
# 67       US                 Red Blend
# 69       US                Chardonnay
# 70       US        Cabernet Sauvignon
# 72       US        Cabernet Sauvignon
# 73       US              Petite Sirah
# 74       US  Bordeaux-style Red Blend
# 77       US                Pinot Noir
# 83       US                 Zinfandel
# 85       US                  Albariño
# 86       US                    Merlot
# 89       US                 Red Blend
# 90       US                Pinot Gris
# 91       US                  Meritage
# 93       US                  Viognier
# 96       US                  Riesling
# 98       US  Bordeaux-style Red Blend
# 99       US                Pinot Gris
# 100      US                  Riesling
# 101      US                  Riesling
# 107      US                 Zinfandel
# 110      US        Cabernet Sauvignon
# 113      US  Bordeaux-style Red Blend
# 114      US                Chardonnay

# %%
pr.columns = ['Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.', 'country', 'variety']
n = len(pr)
spa = stopwords.words("english")
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
reemplazos = []
for r in range(n):
    original = pr.description[r]
    reemplazo = ''
    if original != 'NaN':
        quedar = [stemmer.stem(p) for p in tokenizer.tokenize(original) if p.lower() not in spa]
        reemplazo = ' '.join(quedar)
    reemplazos.append(reemplazo)
pr['limpios'] = reemplazos
texto = ' '.join(reemplazos)
nube = WordCloud().generate(texto)
plt.rcParams["figure.figsize"] = [15, 7]
plt.imshow(nube)
plt.axis("off")
plt.show()
# Out:
#   File "<ipython-input-57-d54beb381679>", line 1
#     pr.columns = ['Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.', 'country', 'variety']
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
df2 = pd.read_csv("rev-solo1.csv")

# %%
df2
# Out:
#                                               description   country  \
# 0       Aromas include tropical fruit broom brimstone ...     Italy
# 1       This is ripe and fruity a wine that is smooth ...  Portugal
# 2       Tart and snappy the flavors of lime flesh and ...        US
# 3       Pineapple rind lemon pith and orange blossom s...        US
# 4       Much like the regular bottling from 2012 this ...        US
# ...                                                   ...       ...
# 129968  Notes of honeysuckle and cantaloupe sweeten th...   Germany
# 129969  Citation is given as much as a decade of bottl...        US
# 129970  Well-drained gravel soil gives this wine its c...    France
# 129971  A dry style of Pinot Gris this is crisp with s...    France
# 129972  Big rich and off-dry this is powered by intens...    France
#
#                variety
# 0          White Blend
# 1       Portuguese Red
# 2           Pinot Gris
# 3             Riesling
# 4           Pinot Noir
# ...                ...
# 129968        Riesling
# 129969      Pinot Noir
# 129970  Gewürztraminer
# 129971      Pinot Gris
# 129972  Gewürztraminer
#
# [129973 rows x 3 columns]

# %% [markdown]
# Con la BDD original se tomaba el primer registro como nombre de columna pero como se vio al inicio se presentaron errores al hacer modificacion y hacer llamar las graficas asi que se modifica desde fuera y se repite el proceso

# %%
clase1 = df2[df2['country']=='US']

# %%
clase1
# Out:
#                                               description country  \
# 2       Tart and snappy the flavors of lime flesh and ...      US
# 3       Pineapple rind lemon pith and orange blossom s...      US
# 4       Much like the regular bottling from 2012 this ...      US
# 10      Soft supple plum envelopes an oaky structure i...      US
# 12      Slightly reduced this wine offers a chalky tan...      US
# ...                                                   ...     ...
# 129947  Hailing from one of the more popular vineyards...      US
# 129951  There's no bones about the use of oak in this ...      US
# 129952  This opens with herbaceous dollops of thyme an...      US
# 129954  This Zinfandel from the eastern section of Nap...      US
# 129969  Citation is given as much as a decade of bottl...      US
#
#                    variety
# 2               Pinot Gris
# 3                 Riesling
# 4               Pinot Noir
# 10      Cabernet Sauvignon
# 12      Cabernet Sauvignon
# ...                    ...
# 129947        Chenin Blanc
# 129951          Chardonnay
# 129952           Zinfandel
# 129954           Zinfandel
# 129969          Pinot Noir
#
# [54504 rows x 3 columns]

# %%
import ssl
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer

if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
n = len(df2)
spa = stopwords.words("english")
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
reemplazos = []
for r in range(n):
    original = df2.description[r]
    reemplazo = ''
    if original != 'NaN':
        quedar = [stemmer.stem(p) for p in tokenizer.tokenize(original) if p.lower() not in spa]
        reemplazo = ' '.join(quedar)
    reemplazos.append(reemplazo)
df2['limpios'] = reemplazos
texto = ' '.join(reemplazos)
nube = WordCloud().generate(texto)
plt.rcParams["figure.figsize"] = [15, 7]
plt.imshow(nube)
plt.axis("off")
plt.show()
